# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo=pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv',sep='\t')
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
item_price = chipo['item_price'].str.replace('$', '').astype(float)
chipo['item_price'] = item_price

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
# precio unitario
chipo["unit_price"] = chipo["item_price"] / chipo["quantity"]

# productos cuyo precio unitario > 10
chipo[chipo["unit_price"] > 10]["item_name"].nunique()
# Out:
# 25

# %% [markdown]
# ### Step 5. What is the price of each item?
# ###### print a data frame with only three columns item_name choice_description and product_price

# %%
chipo[["item_name", "choice_description", "unit_price"]].drop_duplicates(subset="item_name")
# Out:
#                                   item_name  \
# 0              Chips and Fresh Tomato Salsa
# 1                                      Izze
# 2                          Nantucket Nectar
# 3     Chips and Tomatillo-Green Chili Salsa
# 4                              Chicken Bowl
# 6                             Side of Chips
# 7                             Steak Burrito
# 8                          Steak Soft Tacos
# 10                      Chips and Guacamole
# 11                     Chicken Crispy Tacos
# 12                       Chicken Soft Tacos
# 16                          Chicken Burrito
# 18                              Canned Soda
# 21                         Barbacoa Burrito
# 27                         Carnitas Burrito
# 33                            Carnitas Bowl
# 34                            Bottled Water
# 38    Chips and Tomatillo Green Chili Salsa
# 39                            Barbacoa Bowl
# 40                                    Chips
# ...

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
chipo.sort_values(by="item_name")
# Out:
#       order_id  quantity          item_name  \
# 3389      1360         2  6 Pack Soft Drink
# 341        148         1  6 Pack Soft Drink
# 1849       749         1  6 Pack Soft Drink
# 1860       754         1  6 Pack Soft Drink
# 2713      1076         1  6 Pack Soft Drink
# ...        ...       ...                ...
# 2384       948         1  Veggie Soft Tacos
# 781        322         1  Veggie Soft Tacos
# 2851      1132         1  Veggie Soft Tacos
# 1699       688         1  Veggie Soft Tacos
# 1395       567         1  Veggie Soft Tacos
#
#                                      choice_description  item_price  \
# 3389                                        [Diet Coke]       12.98
# 341                                         [Diet Coke]        6.49
# 1849                                             [Coke]        6.49
# 1860                                        [Diet Coke]        6.49
# 2713                                             [Coke]        6.49
# ...

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
tabla = (
    chipo
    .groupby("item_name", as_index=False)
    .agg(
        quantity=("quantity", "sum"),
        unit_price=("unit_price", "mean")
    )
)

# calcular el total
tabla["total"] = tabla["quantity"] * tabla["unit_price"]

# ordenar por unit_price descendente
tabla = tabla.sort_values(by="unit_price", ascending=False)

tabla
# Out:
#                                 item_name  quantity  unit_price        total
# 15                    Carnitas Salad Bowl         6   11.056667    66.340000
# 42                       Steak Salad Bowl        31   11.027931   341.865862
# 4                     Barbacoa Salad Bowl        10   10.640000   106.400000
# 11                          Carnitas Bowl        71   10.315588   732.406765
# 38                             Steak Bowl       221   10.232559  2261.395592
# 1                           Barbacoa Bowl        66   10.187273   672.360000
# 48                      Veggie Salad Bowl        18   10.138889   182.500000
# 3                   Barbacoa Crispy Tacos        12   10.087273   121.047273
# 5                     Barbacoa Soft Tacos        25   10.018400   250.460000
# 44                            Veggie Bowl        87   10.011882   871.033765
# 39                          Steak Burrito       386    9.993424  3857.461630
# ...

# %% [markdown]
# ### Step 8. How many times was a Veggie Salad Bowl ordered?

# %%
print(f'el número de veces que se ordeno el Veggie Salad Bowl fue: {chipo[chipo["item_name"] == "Veggie Salad Bowl"]["quantity"].sum()}')
# Out:
# el número de veces que se ordeno el Veggie Salad Bowl fue: 18

# %% [markdown]
# ### Step 9. How many times did someone order more than one Canned Soda?

# %%
print(f' el número de veces que se ordeno una soda más de una vez: {chipo[(chipo["item_name"] == "Canned Soda")&(chipo["quantity"] > 1)]["quantity"].count()}')
# Out:
#  el número de veces que se ordeno una soda más de una vez: 20
